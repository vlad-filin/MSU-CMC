# %% [markdown]
# ## Visualize datasets(n=2)

# %%
import data
import matplotlib.pyplot as plt
from importlib import reload
reload(data)

# %matplotlib inline

# %%
tmp = data.create_data()
plt.figure(figsize=(6, 6))
for i in range(0,len(tmp)):
    X,y = tmp[i]
    plt.scatter(X[:, 0], X[:, 1], marker='o', c=y,
            s=75, edgecolor='k')
    plt.grid()
    plt.title('dataset #' + str(i))
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.savefig("dataset"  + str(i))
    plt.figure(figsize=(6, 6))

# %% [markdown]
# ## Experiement 1

# %%
import svm as svm
import optimization as Pegasos
import subgrad as subgrad
import time as t
import numpy as np
reload(svm)
reload(subgrad)
# Out:
# <module 'subgrad' from 'C:\\Users\\User\\Contest_Python\\task3\\27.12\\subgrad.py'>

# %%
list_samples = [100, 500, 1000, 2000, 3000]
list_features = [2, 5, 10, 15, 25]
list_classifier = [svm.SVMSolver(C=1, method='primal'), svm.SVMSolver(C=1, method='dual'),
                   subgrad.SubGDClassifier(), subgrad.SSubGDClassifier(10)]
time_fit= {'feat':[],'sample':[]}
time_classifier = []
for clf in list_classifier:
    for sample in list_samples:
        X,y = data.create_data(sample, 5)[0]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['sample'].append(t.time() - t_s)
    for f in list_features:
        X,y = data.create_data(1000, f)[0]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['feat'].append(t.time() - t_s)
    time_classifier.append(time_fit.copy())
    time_fit= {'feat':[],'sample':[]}
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
f, ax1 = plt.subplots()
for name, i in zip(['primal','dual','subGrad','SSubbGrad'], range(0,4)):
    ax1.plot(list_features, np.cumsum(time_classifier[i]['feat']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 1000 объектов и время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество признаков")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e1_d0_f")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f, ax1 = plt.subplots()
for name, i in zip(['primal','dual','subGrad','SSubbGrad'], range(0,4)):
    ax1.plot(list_samples, np.cumsum(time_classifier[i]['sample']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 5 признаков + время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество объектов")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e1_d0_s")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
list_samples = [100, 500, 1000, 2000, 3000]
list_features = [2, 5, 10, 15, 25]
list_classifier = [svm.SVMSolver(C=1, method='primal'), svm.SVMSolver(C=1, method='dual'),
                   subgrad.SubGDClassifier(), subgrad.SSubGDClassifier(10)]
time_fit= {'feat':[],'sample':[]}
time_classifier = []
for clf in list_classifier:
    for sample in list_samples:
        X,y = data.create_data(sample, 5)[1]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['sample'].append(t.time() - t_s)
    for f in list_features:
        X,y = data.create_data(1000, f)[1]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['feat'].append(t.time() - t_s)
    time_classifier.append(time_fit.copy())
    time_fit= {'feat':[],'sample':[]}
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
f, ax1 = plt.subplots()
for name, i in zip(['primal','dual','subGrad','SSubbGrad'], range(0,4)):
    ax1.plot(list_features, np.cumsum(time_classifier[i]['feat']), label=name, lw=3)
ax1.set_title(u"Датасет 1, 1000 объектов и время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество признаков")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e1_d1_f")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f, ax1 = plt.subplots()
for name, i in zip(['primal','dual','subGrad','SSubbGrad'], range(0,4)):
    ax1.plot(list_samples, np.cumsum(time_classifier[i]['sample']), label=name, lw=3)
ax1.set_title(u"Датасет 1, 5 признаков + время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество объектов")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e1_d1_s")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
list_samples = [100, 500, 1000, 2000, 3000]
list_features = [2, 5, 10, 15, 25]
list_classifier = [svm.SVMSolver(C=1, method='primal'), svm.SVMSolver(C=1, method='dual'),
                   subgrad.SubGDClassifier(), subgrad.SSubGDClassifier(10)]
time_fit= {'feat':[],'sample':[]}
time_classifier = []
for clf in list_classifier:
    for sample in list_samples:
        X,y = data.create_data(sample, 5)[2]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['sample'].append(t.time() - t_s)
    for f in list_features:
        X,y = data.create_data(1000, f)[2]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['feat'].append(t.time() - t_s)
    time_classifier.append(time_fit.copy())
    time_fit= {'feat':[],'sample':[]}
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
f, ax1 = plt.subplots()
for name, i in zip(['primal','dual','subGrad','SSubbGrad'], range(0,4)):
    ax1.plot(list_features, np.cumsum(time_classifier[i]['feat']), label=name, lw=3)
ax1.set_title(u"Датасет 2, 1000 объектов и время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество признаков")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e1_d2_f")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f, ax1 = plt.subplots()
for name, i in zip(['primal','dual','subGrad','SSubbGrad'], range(0,4)):
    ax1.plot(list_samples, np.cumsum(time_classifier[i]['sample']), label=name, lw=3)
ax1.set_title(u"Датасет 2, 5 признаков + время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество объектов")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e1_d2_s")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
dataset = data.create_data(1000, 5)
test = data.create_data(100, 5)
name = ['dataset 0', 'dataset 1','dataset 2','dataset 3','dataset 4']
clf = svm.SVMSolver(C=1, method='primal')
acc = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    acc.append(np.mean(clf.predict(X_test) == y_test))

# %%
ans = 'primal'
for x in acc:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"

# %%
print(ans)
# Out:
# primal&1.00&0.49&0.44&1.00&0.86\\

# %%
dataset = data.create_data(1000, 5)
test = data.create_data(100, 5)
name = ['dataset 0', 'dataset 1','dataset 2','dataset 3','dataset 4']
clf = svm.SVMSolver(C=1, method='dual')
acc = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    acc.append(np.mean(clf.predict(X_test) == y_test))

# %%
ans = 'dual'
for x in acc:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
# Out:
# dual&1.00&0.38&0.65&0.93&0.84\\

# %%
clf = subgrad.SubGDClassifier()
acc = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    acc.append(np.mean(clf.predict(X_test) == y_test))
ans = 'SubGrad'
for x in acc:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
# Out:
# SubGrad&0.99&0.38&0.65&1.00&0.50\\

# %%
reload(subgrad)
clf =subgrad.SSubGDClassifier(batch_size=100)
acc = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    acc.append(np.mean(clf.predict(X_test) == y_test))
ans = 'SSubGrad'
for x in acc:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\User\conda3\envs\py35\lib\site-packages\numpy\core\_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# C:\Users\User\Contest_Python\task3\27.12\oracles.py:50: RuntimeWarning: invalid value encountered in greater
#   hinge = np.where(tmp > 0, tmp, np.zeros(tmp.shape))
# SSubGrad&1.00&0.43&0.68&1.00&0.66\\

# %%
X,y = dataset[0]
clf =subgrad.SSubGDClassifier(batch_size=100, C=1e-5)
h = clf.fit(X,y, trace=True, log_freq=0.01)
h
# Out:
# 1.28952246078e-05
# 1.28948138608e-05
# {'epoch_num': [0, 0.1, 0.2],
#  'func': [0.38660171326273407, 1.289561493542605e-05, 1.2895224607794169e-05],
#  'time': [0, 0.001001596450805664, 0.0009992122650146484]}

# %%
dataset = data.create_data(1000, 5)
test = data.create_data(100, 5)
name = ['dataset 0', 'dataset 1','dataset 2','dataset 3','dataset 4']
clf = svm.SVMSolver(C=1, method='primal')
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_primal_objective(X,y))
ans = 'primal'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)

clf = svm.SVMSolver(C=1, method='dual')
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = 'dual'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)   

clf = subgrad.SubGDClassifier()
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.get_objective(X,y))
ans = 'SubGrad'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
clf =subgrad.SSubGDClassifier(batch_size=100)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.get_objective(X,y))
ans = 'SSubGrad'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
# Out:
# primal&0.06&1.00&0.88&0.05&0.49\\
# dual&-0.06&-1.00&-0.88&-0.05&-0.49\\
# SubGrad&0.07&1.00&0.84&0.05&1.66\\
# SSubGrad&0.05&1.00&0.81&0.03&2.19\\

# %% [markdown]
# ## Experiement 2

# %%
list_samples = [100, 500, 1000, 2000, 3000]
list_features = [2, 5, 10, 15, 25]
list_classifier = [svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2),
                   svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3),
                   svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=4),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)]
time_fit= {'feat':[],'sample':[]}
time_classifier = []
for clf in list_classifier:
    for sample in list_samples:
        X,y = data.create_data(sample, 5)[0]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['sample'].append(t.time() - t_s)
    for f in list_features:
        X,y = data.create_data(1000, f)[0]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['feat'].append(t.time() - t_s)
    time_classifier.append(time_fit.copy())
    time_fit= {'feat':[],'sample':[]}

# %%
obj
# Out:
# 'SSubGrad'

# %%
f, ax1 = plt.subplots()
names = ['polynomial, degree=2', 'polynomial, degree=3',
         'polynomial, degree=4', 'rbf, gamma=0.5','rbf, gamma=10','rbf, gamma=100']
for name, i in zip(names, range(0,len(names))):
    ax1.plot(list_features, np.cumsum(time_classifier[i]['feat']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 1000 объектов и время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество признаков")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e2_d0_f")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f, ax1 = plt.subplots()
for name, i in zip(names, range(0,len(names))):
    ax1.plot(list_samples, np.cumsum(time_classifier[i]['sample']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 5 признаков + время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество объектов")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e2_d0_s")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
list_samples = [100, 500, 1000, 2000, 3000]
list_features = [2, 5, 10, 15, 25]
list_classifier = [svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2),
                   svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3),
                   svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=4),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)]
time_fit= {'feat':[],'sample':[]}
time_classifier = []
for clf in list_classifier:
    for sample in list_samples:
        X,y = data.create_data(sample, 5)[1]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['sample'].append(t.time() - t_s)
    for f in list_features:
        X,y = data.create_data(1000, f)[1]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['feat'].append(t.time() - t_s)
    time_classifier.append(time_fit.copy())
    time_fit= {'feat':[],'sample':[]}

# %%
f, ax1 = plt.subplots()
names = ['polynomial, degree=2', 'polynomial, degree=3',
         'polynomial, degree=4', 'rbf, gamma=0.5','rbf, gamma=10','rbf, gamma=100']
for name, i in zip(names, range(0,len(names))):
    ax1.plot(list_features, np.cumsum(time_classifier[i]['feat']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 1000 объектов и время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество признаков")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e2_d1_f")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f, ax1 = plt.subplots()
for name, i in zip(names, range(0,len(names))):
    ax1.plot(list_samples, np.cumsum(time_classifier[i]['sample']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 5 признаков + время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество объектов")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e2_d1_s")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
list_samples = [100, 500, 1000, 2000, 3000]
list_features = [2, 5, 10, 15, 25]
list_classifier = [svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2),
                   svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3),
                   svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=4),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10),
                   svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)]
time_fit= {'feat':[],'sample':[]}
time_classifier = []
for clf in list_classifier:
    for sample in list_samples:
        X,y = data.create_data(sample, 5)[2]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['sample'].append(t.time() - t_s)
    for f in list_features:
        X,y = data.create_data(1000, f)[2]
        t_s = t.time()
        clf.fit(X,y)
        time_fit['feat'].append(t.time() - t_s)
    time_classifier.append(time_fit.copy())
    time_fit= {'feat':[],'sample':[]}

# %%
f, ax1 = plt.subplots()
names = ['polynomial, degree=2', 'polynomial, degree=3',
         'polynomial, degree=4', 'rbf, gamma=0.5','rbf, gamma=10','rbf, gamma=100']
for name, i in zip(names, range(0,len(names))):
    ax1.plot(list_features, np.cumsum(time_classifier[i]['feat']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 1000 объектов и время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество признаков")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e2_d2_f")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
f, ax1 = plt.subplots()
for name, i in zip(names, range(0,len(names))):
    ax1.plot(list_samples, np.cumsum(time_classifier[i]['sample']), label=name, lw=3)
ax1.set_title(u"Датасет 0, 5 признаков + время работы")
ax1.set_ylabel(u"Время")
ax1.set_xlabel(u"Количество объектов")
ax1.grid()
ax1.legend()


f.show()
f.savefig("e2_d2_s")
# Out:
# C:\Users\User\conda3\envs\py35\lib\site-packages\matplotlib\figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
dataset = data.create_data(1000, 5)
test = data.create_data(100, 5)
name = ['dataset 0', 'dataset 1','dataset 2','dataset 3','dataset 4']
clf = svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = 'poli, degree=2'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
print("\\hline")
clf = svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = ans = 'poli, degree=3'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
print("\\hline")
clf = svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=4)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = ans = 'poli, degree=4'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans) 
print("\\hline")
clf = svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = ans = 'rbf, gamma=0.5'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans) 
print("\\hline")
clf = svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = ans = 'rbf, gamma=10'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
print("\\hline")
clf = svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)
obj = []
for i in range(0, len(dataset)):
    X,y = dataset[i]
    clf.fit(X,y)
    X_test, y_test = test[i]
    obj.append(clf.compute_dual_objective(X,y))
ans = ans = 'rbf, gamma=100'
for x in obj:
    ans+= '&'
    s = "%.2f" % (x)
    ans += s 
ans+="\\\\"
print(ans)
print("\\hline")
# Out:
# poli, degree=2&-0.04&-0.62&-0.80&-0.03&-0.44\\
# \hline
# poli, degree=3&-0.00&-0.43&-0.72&-0.00&-0.32\\
# \hline
# poli, degree=4&-0.00&-0.17&-0.64&-0.00&-0.30\\
# \hline
# rbf, gamma=0.5&-0.98&-0.96&-1.00&-0.20&-0.98\\
# \hline
# rbf, gamma=10&-1.00&-0.97&-1.00&-0.20&-0.99\\
# \hline
# rbf, gamma=100&-1.00&-0.97&-1.00&-0.20&-0.99\\
# \hline

# %% [markdown]
# ## Experiement 8

# %%
def make_meshgrid(x, y, h=.02):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on
    y: data to base y-axis meshgrid on
    h: stepsize for meshgrid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy


def plot_contours(ax, clf, xx, yy, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

# %%
dataset = data.create_data(100,2)
models = [svm.SVMSolver(C=1, method='dual'),
          svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2),
          svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)]
titles = ['linear', 'polynomial, degree=2', 'polynomial, degree=3',
         'rbf, gamma=0.5',
          'rbf, gamma=10','rbf, gamma=100',]

# %%
X, y = dataset[0]
for m in models:
    m.fit(X,y)
fig, sub = plt.subplots(2, 3, figsize=(12,10))
plt.subplots_adjust(wspace=0.4, hspace=0.4) # ?
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)
for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.savefig("d0_all")

# %%
fig, sub = plt.subplots(2, 3, figsize=(12,10))
plt.subplots_adjust(wspace=0.4, hspace=0.4) # ?
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)
for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    sup = clf.support
    ax.scatter(sup[:,0], sup[:,1], c=clf.y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.savefig("d0_sup")

# %%
X, y = dataset[1]
y[y==0]= -1
models = [svm.SVMSolver(C=1, method='dual'),
          svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2),
          svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)]
for m in models:
    m.fit(X,y)
fig, sub = plt.subplots(2, 3, figsize=(12,10))
plt.subplots_adjust(wspace=0.4, hspace=0.4) # ?
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)
for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.savefig("d1_all")

# %%
fig, sub = plt.subplots(2, 3, figsize=(12,10))
plt.subplots_adjust(wspace=0.4, hspace=0.4) # ?
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)
for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    sup = clf.support
    ax.scatter(sup[:,0], sup[:,1], c=clf.y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.savefig("d1_sup")

# %%
from sklearn.datasets import make_moons
X, y = make_moons(100)
y[y==0] = -1
models = [svm.SVMSolver(C=1, method='dual'),
          svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=2),
          svm.SVMSolver(C=1, method='dual', kernel='polynomial', degree=3),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=0.5),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=10),
          svm.SVMSolver(C=1, method='dual', kernel='rbf', gamma=100)]
for m in models:
    m.fit(X,y)
fig, sub = plt.subplots(2, 3, figsize=(12,10))
plt.subplots_adjust(wspace=0.4, hspace=0.4) # ?
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)
for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.savefig("dm_all")

# %%
fig, sub = plt.subplots(2, 3, figsize=(12,10))
plt.subplots_adjust(wspace=0.4, hspace=0.4) # ?
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)
for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    sup = clf.support
    ax.scatter(sup[:,0], sup[:,1], c=clf.y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('x1')
    ax.set_ylabel('x2')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)
plt.savefig("dm_sup")
